# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('../../tribe_dynamics_data.csv')
df.head(1)
# Out:
#    Unnamed: 0  Unnamed: 0.1  brand_id                        worker_id  \
# 0           0             0     18792  TRIBE_103_allayne.low@gmail.com
#
#    mturker                         post_hash  answer        date  \
# 0    False  3ca62dcea583b7aa204fc52fe6b2826c   False  2017-07-16
#
#    duration_seconds                                               text  \
# 0               NaN  ・\r\nケイト スペード ニューヨークの\r\n2017Fall Collectionに招...
#
#    model_decision timestamped_model lang
# 0           False               NaN   ja

# %% [markdown]
# # Drop unnecessary columns

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
df.head(1)
# Out:
#    brand_id                        worker_id  mturker  \
# 0     18792  TRIBE_103_allayne.low@gmail.com    False
#
#                           post_hash  answer        date  duration_seconds  \
# 0  3ca62dcea583b7aa204fc52fe6b2826c   False  2017-07-16               NaN
#
#                                                 text  model_decision  \
# 0  ・\r\nケイト スペード ニューヨークの\r\n2017Fall Collectionに招...           False
#
#   timestamped_model lang
# 0               NaN   ja

# %% [markdown]
# # Reduce to only relevant features

# %%
df_small = df[['text','lang','model_decision','answer','mturker']]
df_small.head(3)
# Out:
#                                                 text lang  model_decision  \
# 0  ・\r\nケイト スペード ニューヨークの\r\n2017Fall Collectionに招...   ja           False
# 1  青春日記【挨拶のハグじゃダメなの】\r\n僕が中学3年生の時だ。\r\n高山私立松倉中学校と...   ja           False
# 2  fabric&thingsで本日のみ開催しております\r\nいちごのプチレストラン La F...   ja           False
#
#    answer  mturker
# 0   False    False
# 1   False    False
# 2   False    False

# %% [markdown]
# # Extract posts from a fixed language

# %%
language = 'it'
lang_df = df_small[df_small.lang == language]
lang_df.head(3)
# Out:
#                                                   text lang  model_decision  \
# 130  Lottie Moss e Alex Mytton, è amore? Rilassarsi...   it           False
# 132  Lottie Moss e Alex Mytton, è amore? Rilassarsi...   it           False
# 134  Lottie Moss e Alex Mytton, è amore? Rilassarsi...   it           False
#
#      answer  mturker
# 130   False     True
# 132   False     True
# 134   False     True

# %%
print('Dataset contains {} "{}" posts'.format(lang_df.shape[0], language))
# Out:
# Dataset contains 469 "it" posts

# %% [markdown]
# # Extract all posts as a list of posts

# %%
texts_arr = lang_df.text.values

# %%
unique_texts_arr = np.unique(texts_arr)

# %%
print('Dataset contains {} distinct "{}" posts'.format(len(unique_texts_arr), language))
# Out:
# Dataset contains 130 distinct "it" posts

# %%
lang_no_dup_df = lang_df.drop_duplicates(inplace=False)

# %%
print('No duplicates dataset contains {} "{}" posts'.format(lang_no_dup_df.shape[0], language))
# Out:
# No duplicates dataset contains 136 "it" posts

# %% [markdown]
# # N-grams

# %%
post_number = 1 # extract post at this position in the list
n = 3 # number of grams (n of n-grams)

# %%
from nltk import ngrams

one_post = lang_no_dup_df.text.values[post_number]

print('TEXT OF THE SELECTED POST: \n{}'.format(one_post))
# Out:
# TEXT OF THE SELECTED POST:
# Da Serena Williams a Giovanna Mezzogiorno: quando la maternità è sovrana «Mio caro bambino, tu mi hai dato la forza che non pensavo di avere: non vedo l’ora di conoscerti e vederti il prossimo anno nel box giocatori». Nella lettera che Serena Williams ha scritto al figlio in arrivo c’è praticamente tutto: il sapersi fermare, il valore di quell’attesa e un dolce sguardo al futuro. La tennista ameriana, tornata numero uno al mondo, è la grande assente degli Internazionali di Roma, e non ci sarà neppure per i prossimi impegni stagionali: si è presa una pausa-maternità.
# LEGGI ANCHESerena Williams: «Sogno che mio figlio mi veda giocare»
# Meritata, sacrosanta. Che non mette assolutamente a repentaglio la sua strepitosa e già lunga carriera: Serena tornerà, lo dice lei stessa, magari anche più forte di prima. Trattatasi solo di uno stop momentaneo, lo stesso che ha annunciato Adele nella data conclusiva del suo ultimo tour: «Arrivederci, ci rivediamo tra due anni, adesso voglio avere un altro figlio. Ma tranquilli, non vi libererete di me». Possono star sereni sia i suoi fan, sia quelli della collega Beyoncé, in attesa di due gemelli.
# Cantanti che si fermano subito, o che resistono fino alla fine della tournée, come Laura Pausini. D’altronde si sa, in questi casi la pausa maternità può essere più o meno lunga: «Dopo il primo figlio sono tornata subito a lavoro, col secondo invece me la sono goduta riprendendomi le mie domeniche e i riti familiari», sono le parole della conduttrice Ilaria D’Amico. Stop lungo, ma non lunghissimo, altrimenti si rischia di essere criticati: è successo a Kate Middleton dopo la nascita della secondogenita.
# Pause volute, o pause forzate: «Tre anni lontana dal set sono tanti», riconosce Giovanna Mezzogiorno, provata dalla nascita dei suoi due gemelli. «La maternità è una gioia, ma anche una fatica». L’opposto di Anne Hathaway che non ha rallentato i suoi ritmi. Magari poi i figli portano pure fortuna, come a Ilary Blasi che dopo i tre parti ha sempre avuto delle ottime novità lavorative: «Ho detto no a rinunce e sacrifici, mi sono goduta la maternità», ha dichiarato reduce dal parto della piccola Isabel.
# C’è chi addirittura è riuscita a continuare a lavorare col pancione, come le modelle Bianca Balti e Irina Shayk, diventate proprio per questo dei simboli. Oppure l’attrice Emily Deschanel, che dopo essersi messa a piangere per aver scoperto di essere incinta perché credeva che avrebbe rovinato la storica serie tv nella quale stava lavorando, ha scoperto che pure il suo personaggio avrebbe potuto avere un figlio: due parole con gli sceneggiatori e la soluzione è stata trovata, per il bene di tutti.
# Insomma, in certi casi – anche se è sempre più difficile – il compromesso col lavoro è necessario. Perché «la gravidanza non deve essere un ostacolo alla carriera di una donna».
# LEGGI ANCHEIlaria D'Amico: «La maternità è volata»
# L'articolo Da Serena Williams a Giovanna Mezzogiorno: quando la maternità è sovrana proviene da VanityFair.it.

# %%
print('{}-grams "decomposition":'.format(n))

n_grams = ngrams(one_post.split(), n)
for grams in n_grams:
    print(grams)
# Out:
# 3-grams "decomposition":
# ('Da', 'Serena', 'Williams')
# ('Serena', 'Williams', 'a')
# ('Williams', 'a', 'Giovanna')
# ('a', 'Giovanna', 'Mezzogiorno:')
# ('Giovanna', 'Mezzogiorno:', 'quando')
# ('Mezzogiorno:', 'quando', 'la')
# ('quando', 'la', 'maternità')
# ('la', 'maternità', 'è')
# ('maternità', 'è', 'sovrana')
# ('è', 'sovrana', '«Mio')
# ('sovrana', '«Mio', 'caro')
# ('«Mio', 'caro', 'bambino,')
# ('caro', 'bambino,', 'tu')
# ('bambino,', 'tu', 'mi')
# ('tu', 'mi', 'hai')
# ('mi', 'hai', 'dato')
# ('hai', 'dato', 'la')
# ('dato', 'la', 'forza')
# ('la', 'forza', 'che')
# ('forza', 'che', 'non')
# ('che', 'non', 'pensavo')
# ('non', 'pensavo', 'di')
# ('pensavo', 'di', 'avere:')
# ('di', 'avere:', 'non')
# ('avere:', 'non', 'vedo')
# ('non', 'vedo', 'l’ora')
# ('vedo', 'l’ora', 'di')
# ('l’ora', 'di', 'conoscerti')
# ('di', 'conoscerti', 'e')
# ('conoscerti', 'e', 'vederti')
# ('e', 'vederti', 'il')
# ('vederti', 'il', 'prossimo')
# ('il', 'prossimo', 'anno')
# ('prossimo', 'anno', 'nel')
# ('anno', 'nel', 'box')
# ('nel', 'box', 'giocatori».')
# ('box', 'giocatori».', 'Nella')
# ('giocatori».', 'Nella', 'lettera')
# ('Nella', 'lettera', 'che')
# ('lettera', 'che', 'Serena')
# ('che', 'Serena', 'Williams')
# ('Serena', 'Williams', 'ha')
# ('Williams', 'ha', 'scritto')
# ('ha', 'scritto', 'al')
# ('scritto', 'al', 'figlio')
# ('al', 'figlio', 'in')
# ('figlio', 'in', 'arrivo')
# ('in', 'arrivo', 'c’è')
# ('arrivo', 'c’è', 'praticamente')
# ('c’è', 'praticamente', 'tutto:')
# ('praticamente', 'tutto:', 'il')
# ('tutto:', 'il', 'sapersi')
# ('il', 'sapersi', 'fermare,')
# ('sapersi', 'fermare,', 'il')
# ('fermare,', 'il', 'valore')
# ('il', 'valore', 'di')
# ('valore', 'di', 'quell’attesa')
# ('di', 'quell’attesa', 'e')
# ('quell’attesa', 'e', 'un')
# ('e', 'un', 'dolce')
# ('un', 'dolce', 'sguardo')
# ('dolce', 'sguardo', 'al')
# ('sguardo', 'al', 'futuro.')
# ('al', 'futuro.', 'La')
# ('futuro.', 'La', 'tennista')
# ('La', 'tennista', 'ameriana,')
# ('tennista', 'ameriana,', 'tornata')
# ('ameriana,', 'tornata', 'numero')
# ('tornata', 'numero', 'uno')
# ('numero', 'uno', 'al')
# ('uno', 'al', 'mondo,')
# ('al', 'mondo,', 'è')
# ('mondo,', 'è', 'la')
# ('è', 'la', 'grande')
# ('la', 'grande', 'assente')
# ('grande', 'assente', 'degli')
# ('assente', 'degli', 'Internazionali')
# ('degli', 'Internazionali', 'di')
# ('Internazionali', 'di', 'Roma,')
# ('di', 'Roma,', 'e')
# ('Roma,', 'e', 'non')
# ('e', 'non', 'ci')
# ('non', 'ci', 'sarà')
# ('ci', 'sarà', 'neppure')
# ('sarà', 'neppure', 'per')
# ('neppure', 'per', 'i')
# ('per', 'i', 'prossimi')
# ('i', 'prossimi', 'impegni')
# ('prossimi', 'impegni', 'stagionali:')
# ('impegni', 'stagionali:', 'si')
# ('stagionali:', 'si', 'è')
# ('si', 'è', 'presa')
# ('è', 'presa', 'una')
# ('presa', 'una', 'pausa-maternità.')
# ('una', 'pausa-maternità.', 'LEGGI')
# ('pausa-maternità.', 'LEGGI', 'ANCHESerena')
# ('LEGGI', 'ANCHESerena', 'Williams:')
# ('ANCHESerena', 'Williams:', '«Sogno')
# ('Williams:', '«Sogno', 'che')
# ('«Sogno', 'che', 'mio')
# ('che', 'mio', 'figlio')
# ('mio', 'figlio', 'mi')
# ('figlio', 'mi', 'veda')
# ('mi', 'veda', 'giocare»')
# ('veda', 'giocare»', 'Meritata,')
# ('giocare»', 'Meritata,', 'sacrosanta.')
# ('Meritata,', 'sacrosanta.', 'Che')
# ('sacrosanta.', 'Che', 'non')
# ('Che', 'non', 'mette')
# ('non', 'mette', 'assolutamente')
# ('mette', 'assolutamente', 'a')
# ('assolutamente', 'a', 'repentaglio')
# ('a', 'repentaglio', 'la')
# ('repentaglio', 'la', 'sua')
# ('la', 'sua', 'strepitosa')
# ('sua', 'strepitosa', 'e')
# ('strepitosa', 'e', 'già')
# ('e', 'già', 'lunga')
# ('già', 'lunga', 'carriera:')
# ('lunga', 'carriera:', 'Serena')
# ('carriera:', 'Serena', 'tornerà,')
# ('Serena', 'tornerà,', 'lo')
# ('tornerà,', 'lo', 'dice')
# ('lo', 'dice', 'lei')
# ('dice', 'lei', 'stessa,')
# ('lei', 'stessa,', 'magari')
# ('stessa,', 'magari', 'anche')
# ('magari', 'anche', 'più')
# ('anche', 'più', 'forte')
# ('più', 'forte', 'di')
# ('forte', 'di', 'prima.')
# ('di', 'prima.', 'Trattatasi')
# ('prima.', 'Trattatasi', 'solo')
# ('Trattatasi', 'solo', 'di')
# ('solo', 'di', 'uno')
# ('di', 'uno', 'stop')
# ('uno', 'stop', 'momentaneo,')
# ('stop', 'momentaneo,', 'lo')
# ('momentaneo,', 'lo', 'stesso')
# ('lo', 'stesso', 'che')
# ('stesso', 'che', 'ha')
# ('che', 'ha', 'annunciato')
# ('ha', 'annunciato', 'Adele')
# ('annunciato', 'Adele', 'nella')
# ('Adele', 'nella', 'data')
# ('nella', 'data', 'conclusiva')
# ('data', 'conclusiva', 'del')
# ('conclusiva', 'del', 'suo')
# ('del', 'suo', 'ultimo')
# ('suo', 'ultimo', 'tour:')
# ('ultimo', 'tour:', '«Arrivederci,')
# ('tour:', '«Arrivederci,', 'ci')
# ('«Arrivederci,', 'ci', 'rivediamo')
# ('ci', 'rivediamo', 'tra')
# ('rivediamo', 'tra', 'due')
# ('tra', 'due', 'anni,')
# ('due', 'anni,', 'adesso')
# ('anni,', 'adesso', 'voglio')
# ('adesso', 'voglio', 'avere')
# ('voglio', 'avere', 'un')
# ('avere', 'un', 'altro')
# ('un', 'altro', 'figlio.')
# ('altro', 'figlio.', 'Ma')
# ('figlio.', 'Ma', 'tranquilli,')
# ('Ma', 'tranquilli,', 'non')
# ('tranquilli,', 'non', 'vi')
# ('non', 'vi', 'libererete')
# ('vi', 'libererete', 'di')
# ('libererete', 'di', 'me».')
# ('di', 'me».', 'Possono')
# ('me».', 'Possono', 'star')
# ('Possono', 'star', 'sereni')
# ('star', 'sereni', 'sia')
# ('sereni', 'sia', 'i')
# ('sia', 'i', 'suoi')
# ('i', 'suoi', 'fan,')
# ('suoi', 'fan,', 'sia')
# ('fan,', 'sia', 'quelli')
# ('sia', 'quelli', 'della')
# ('quelli', 'della', 'collega')
# ('della', 'collega', 'Beyoncé,')
# ('collega', 'Beyoncé,', 'in')
# ('Beyoncé,', 'in', 'attesa')
# ('in', 'attesa', 'di')
# ('attesa', 'di', 'due')
# ('di', 'due', 'gemelli.')
# ('due', 'gemelli.', 'Cantanti')
# ('gemelli.', 'Cantanti', 'che')
# ('Cantanti', 'che', 'si')
# ('che', 'si', 'fermano')
# ('si', 'fermano', 'subito,')
# ('fermano', 'subito,', 'o')
# ('subito,', 'o', 'che')
# ('o', 'che', 'resistono')
# ('che', 'resistono', 'fino')
# ('resistono', 'fino', 'alla')
# ('fino', 'alla', 'fine')
# ('alla', 'fine', 'della')
# ('fine', 'della', 'tournée,')
# ('della', 'tournée,', 'come')
# ('tournée,', 'come', 'Laura')
# ('come', 'Laura', 'Pausini.')
# ('Laura', 'Pausini.', 'D’altronde')
# ('Pausini.', 'D’altronde', 'si')
# ('D’altronde', 'si', 'sa,')
# ('si', 'sa,', 'in')
# ('sa,', 'in', 'questi')
# ('in', 'questi', 'casi')
# ('questi', 'casi', 'la')
# ('casi', 'la', 'pausa')
# ('la', 'pausa', 'maternità')
# ('pausa', 'maternità', 'può')
# ('maternità', 'può', 'essere')
# ('può', 'essere', 'più')
# ('essere', 'più', 'o')
# ('più', 'o', 'meno')
# ('o', 'meno', 'lunga:')
# ('meno', 'lunga:', '«Dopo')
# ('lunga:', '«Dopo', 'il')
# ('«Dopo', 'il', 'primo')
# ('il', 'primo', 'figlio')
# ('primo', 'figlio', 'sono')
# ('figlio', 'sono', 'tornata')
# ('sono', 'tornata', 'subito')
# ('tornata', 'subito', 'a')
# ('subito', 'a', 'lavoro,')
# ('a', 'lavoro,', 'col')
# ('lavoro,', 'col', 'secondo')
# ('col', 'secondo', 'invece')
# ('secondo', 'invece', 'me')
# ('invece', 'me', 'la')
# ('me', 'la', 'sono')
# ('la', 'sono', 'goduta')
# ('sono', 'goduta', 'riprendendomi')
# ('goduta', 'riprendendomi', 'le')
# ('riprendendomi', 'le', 'mie')
# ('le', 'mie', 'domeniche')
# ('mie', 'domeniche', 'e')
# ('domeniche', 'e', 'i')
# ('e', 'i', 'riti')
# ('i', 'riti', 'familiari»,')
# ('riti', 'familiari»,', 'sono')
# ('familiari»,', 'sono', 'le')
# ('sono', 'le', 'parole')
# ('le', 'parole', 'della')
# ('parole', 'della', 'conduttrice')
# ('della', 'conduttrice', 'Ilaria')
# ('conduttrice', 'Ilaria', 'D’Amico.')
# ('Ilaria', 'D’Amico.', 'Stop')
# ('D’Amico.', 'Stop', 'lungo,')
# ('Stop', 'lungo,', 'ma')
# ('lungo,', 'ma', 'non')
# ('ma', 'non', 'lunghissimo,')
# ('non', 'lunghissimo,', 'altrimenti')
# ('lunghissimo,', 'altrimenti', 'si')
# ('altrimenti', 'si', 'rischia')
# ('si', 'rischia', 'di')
# ('rischia', 'di', 'essere')
# ('di', 'essere', 'criticati:')
# ('essere', 'criticati:', 'è')
# ('criticati:', 'è', 'successo')
# ('è', 'successo', 'a')
# ('successo', 'a', 'Kate')
# ('a', 'Kate', 'Middleton')
# ('Kate', 'Middleton', 'dopo')
# ('Middleton', 'dopo', 'la')
# ('dopo', 'la', 'nascita')
# ('la', 'nascita', 'della')
# ('nascita', 'della', 'secondogenita.')
# ('della', 'secondogenita.', 'Pause')
# ('secondogenita.', 'Pause', 'volute,')
# ('Pause', 'volute,', 'o')
# ('volute,', 'o', 'pause')
# ('o', 'pause', 'forzate:')
# ('pause', 'forzate:', '«Tre')
# ('forzate:', '«Tre', 'anni')
# ('«Tre', 'anni', 'lontana')
# ('anni', 'lontana', 'dal')
# ('lontana', 'dal', 'set')
# ('dal', 'set', 'sono')
# ('set', 'sono', 'tanti»,')
# ('sono', 'tanti»,', 'riconosce')
# ('tanti»,', 'riconosce', 'Giovanna')
# ('riconosce', 'Giovanna', 'Mezzogiorno,')
# ('Giovanna', 'Mezzogiorno,', 'provata')
# ('Mezzogiorno,', 'provata', 'dalla')
# ('provata', 'dalla', 'nascita')
# ('dalla', 'nascita', 'dei')
# ('nascita', 'dei', 'suoi')
# ('dei', 'suoi', 'due')
# ('suoi', 'due', 'gemelli.')
# ('due', 'gemelli.', '«La')
# ('gemelli.', '«La', 'maternità')
# ('«La', 'maternità', 'è')
# ('maternità', 'è', 'una')
# ('è', 'una', 'gioia,')
# ('una', 'gioia,', 'ma')
# ('gioia,', 'ma', 'anche')
# ('ma', 'anche', 'una')
# ('anche', 'una', 'fatica».')
# ('una', 'fatica».', 'L’opposto')
# ('fatica».', 'L’opposto', 'di')
# ('L’opposto', 'di', 'Anne')
# ('di', 'Anne', 'Hathaway')
# ('Anne', 'Hathaway', 'che')
# ('Hathaway', 'che', 'non')
# ('che', 'non', 'ha')
# ('non', 'ha', 'rallentato')
# ('ha', 'rallentato', 'i')
# ('rallentato', 'i', 'suoi')
# ('i', 'suoi', 'ritmi.')
# ('suoi', 'ritmi.', 'Magari')
# ('ritmi.', 'Magari', 'poi')
# ('Magari', 'poi', 'i')
# ('poi', 'i', 'figli')
# ('i', 'figli', 'portano')
# ('figli', 'portano', 'pure')
# ('portano', 'pure', 'fortuna,')
# ('pure', 'fortuna,', 'come')
# ('fortuna,', 'come', 'a')
# ('come', 'a', 'Ilary')
# ('a', 'Ilary', 'Blasi')
# ('Ilary', 'Blasi', 'che')
# ('Blasi', 'che', 'dopo')
# ('che', 'dopo', 'i')
# ('dopo', 'i', 'tre')
# ('i', 'tre', 'parti')
# ('tre', 'parti', 'ha')
# ('parti', 'ha', 'sempre')
# ('ha', 'sempre', 'avuto')
# ('sempre', 'avuto', 'delle')
# ('avuto', 'delle', 'ottime')
# ('delle', 'ottime', 'novità')
# ('ottime', 'novità', 'lavorative:')
# ('novità', 'lavorative:', '«Ho')
# ('lavorative:', '«Ho', 'detto')
# ('«Ho', 'detto', 'no')
# ('detto', 'no', 'a')
# ('no', 'a', 'rinunce')
# ('a', 'rinunce', 'e')
# ('rinunce', 'e', 'sacrifici,')
# ('e', 'sacrifici,', 'mi')
# ('sacrifici,', 'mi', 'sono')
# ('mi', 'sono', 'goduta')
# ('sono', 'goduta', 'la')
# ('goduta', 'la', 'maternità»,')
# ('la', 'maternità»,', 'ha')
# ('maternità»,', 'ha', 'dichiarato')
# ('ha', 'dichiarato', 'reduce')
# ('dichiarato', 'reduce', 'dal')
# ('reduce', 'dal', 'parto')
# ('dal', 'parto', 'della')
# ('parto', 'della', 'piccola')
# ('della', 'piccola', 'Isabel.')
# ('piccola', 'Isabel.', 'C’è')
# ('Isabel.', 'C’è', 'chi')
# ('C’è', 'chi', 'addirittura')
# ('chi', 'addirittura', 'è')
# ('addirittura', 'è', 'riuscita')
# ('è', 'riuscita', 'a')
# ('riuscita', 'a', 'continuare')
# ('a', 'continuare', 'a')
# ('continuare', 'a', 'lavorare')
# ('a', 'lavorare', 'col')
# ('lavorare', 'col', 'pancione,')
# ('col', 'pancione,', 'come')
# ('pancione,', 'come', 'le')
# ('come', 'le', 'modelle')
# ('le', 'modelle', 'Bianca')
# ('modelle', 'Bianca', 'Balti')
# ('Bianca', 'Balti', 'e')
# ('Balti', 'e', 'Irina')
# ('e', 'Irina', 'Shayk,')
# ('Irina', 'Shayk,', 'diventate')
# ('Shayk,', 'diventate', 'proprio')
# ('diventate', 'proprio', 'per')
# ('proprio', 'per', 'questo')
# ('per', 'questo', 'dei')
# ('questo', 'dei', 'simboli.')
# ('dei', 'simboli.', 'Oppure')
# ('simboli.', 'Oppure', 'l’attrice')
# ('Oppure', 'l’attrice', 'Emily')
# ('l’attrice', 'Emily', 'Deschanel,')
# ('Emily', 'Deschanel,', 'che')
# ('Deschanel,', 'che', 'dopo')
# ('che', 'dopo', 'essersi')
# ('dopo', 'essersi', 'messa')
# ('essersi', 'messa', 'a')
# ('messa', 'a', 'piangere')
# ('a', 'piangere', 'per')
# ('piangere', 'per', 'aver')
# ('per', 'aver', 'scoperto')
# ('aver', 'scoperto', 'di')
# ('scoperto', 'di', 'essere')
# ('di', 'essere', 'incinta')
# ('essere', 'incinta', 'perché')
# ('incinta', 'perché', 'credeva')
# ('perché', 'credeva', 'che')
# ('credeva', 'che', 'avrebbe')
# ('che', 'avrebbe', 'rovinato')
# ('avrebbe', 'rovinato', 'la')
# ('rovinato', 'la', 'storica')
# ('la', 'storica', 'serie')
# ('storica', 'serie', 'tv')
# ('serie', 'tv', 'nella')
# ('tv', 'nella', 'quale')
# ('nella', 'quale', 'stava')
# ('quale', 'stava', 'lavorando,')
# ('stava', 'lavorando,', 'ha')
# ('lavorando,', 'ha', 'scoperto')
# ('ha', 'scoperto', 'che')
# ('scoperto', 'che', 'pure')
# ('che', 'pure', 'il')
# ('pure', 'il', 'suo')
# ('il', 'suo', 'personaggio')
# ('suo', 'personaggio', 'avrebbe')
# ('personaggio', 'avrebbe', 'potuto')
# ('avrebbe', 'potuto', 'avere')
# ('potuto', 'avere', 'un')
# ('avere', 'un', 'figlio:')
# ('un', 'figlio:', 'due')
# ('figlio:', 'due', 'parole')
# ('due', 'parole', 'con')
# ('parole', 'con', 'gli')
# ('con', 'gli', 'sceneggiatori')
# ('gli', 'sceneggiatori', 'e')
# ('sceneggiatori', 'e', 'la')
# ('e', 'la', 'soluzione')
# ('la', 'soluzione', 'è')
# ('soluzione', 'è', 'stata')
# ('è', 'stata', 'trovata,')
# ('stata', 'trovata,', 'per')
# ('trovata,', 'per', 'il')
# ('per', 'il', 'bene')
# ('il', 'bene', 'di')
# ('bene', 'di', 'tutti.')
# ('di', 'tutti.', 'Insomma,')
# ('tutti.', 'Insomma,', 'in')
# ('Insomma,', 'in', 'certi')
# ('in', 'certi', 'casi')
# ('certi', 'casi', '–')
# ('casi', '–', 'anche')
# ('–', 'anche', 'se')
# ('anche', 'se', 'è')
# ('se', 'è', 'sempre')
# ('è', 'sempre', 'più')
# ('sempre', 'più', 'difficile')
# ('più', 'difficile', '–')
# ('difficile', '–', 'il')
# ('–', 'il', 'compromesso')
# ('il', 'compromesso', 'col')
# ('compromesso', 'col', 'lavoro')
# ('col', 'lavoro', 'è')
# ('lavoro', 'è', 'necessario.')
# ('è', 'necessario.', 'Perché')
# ('necessario.', 'Perché', '«la')
# ('Perché', '«la', 'gravidanza')
# ('«la', 'gravidanza', 'non')
# ('gravidanza', 'non', 'deve')
# ('non', 'deve', 'essere')
# ('deve', 'essere', 'un')
# ('essere', 'un', 'ostacolo')
# ('un', 'ostacolo', 'alla')
# ('ostacolo', 'alla', 'carriera')
# ('alla', 'carriera', 'di')
# ('carriera', 'di', 'una')
# ('di', 'una', 'donna».')
# ('una', 'donna».', 'LEGGI')
# ('donna».', 'LEGGI', 'ANCHEIlaria')
# ('LEGGI', 'ANCHEIlaria', "D'Amico:")
# ('ANCHEIlaria', "D'Amico:", '«La')
# ("D'Amico:", '«La', 'maternità')
# ('«La', 'maternità', 'è')
# ('maternità', 'è', 'volata»')
# ('è', 'volata»', "L'articolo")
# ('volata»', "L'articolo", 'Da')
# ("L'articolo", 'Da', 'Serena')
# ('Da', 'Serena', 'Williams')
# ('Serena', 'Williams', 'a')
# ('Williams', 'a', 'Giovanna')
# ('a', 'Giovanna', 'Mezzogiorno:')
# ('Giovanna', 'Mezzogiorno:', 'quando')
# ('Mezzogiorno:', 'quando', 'la')
# ('quando', 'la', 'maternità')
# ('la', 'maternità', 'è')
# ('maternità', 'è', 'sovrana')
# ('è', 'sovrana', 'proviene')
# ('sovrana', 'proviene', 'da')
# ('proviene', 'da', 'VanityFair.it.')
